# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
std_normal=np.random.normal(loc=0.0, scale=1.0, size=1000)

# %%
a=[]
for i in range(0,101):
    a.append(np.percentile(std_normal,i))

# %%
# Out:
# array([-3.95517014, -2.2940365 , -2.14636853, -2.01399879, -1.78875203,
#        -1.70153617, -1.65893476, -1.57757871, -1.52607808, -1.4326004 ,
#        -1.35759392, -1.30042631, -1.20393527, -1.18044964, -1.14032885,
#        -1.09596267, -1.07630954, -1.04666473, -1.01331183, -0.96570371,
#        -0.91733811, -0.87897071, -0.84651393, -0.81139177, -0.77152755,
#        -0.72802918, -0.70707993, -0.6729174 , -0.63679007, -0.59572454,
#        -0.56775686, -0.53626094, -0.51893105, -0.4995313 , -0.47572941,
#        -0.45569913, -0.43699274, -0.41447073, -0.38159484, -0.35866248,
#        -0.34006328, -0.30785678, -0.27521622, -0.25660356, -0.22544682,
#        -0.21183452, -0.18762881, -0.16254884, -0.1374326 , -0.11261012,
#        -0.08401837, -0.05977747, -0.03336459, -0.01391611,  0.01010323,
#         0.04165287,  0.06033847,  0.09336633,  0.11659117,  0.16087325,
#         0.19056207,  0.20865816,  0.23412558,  0.2866572 ,  0.31439935,
# ...

# %%
rand_dist=np.random.normal(loc=20, scale=8, size=5000)

# %%
stats.probplot(std_normal,dist='norm',plot=plt)
plt.show()

# %%
stats.probplot(np.percentile(std_normal,range(0,101)),dist='norm',plot=plt)
plt.show()
